# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_df = pd.read_excel("D:\Oct_23\sales_cable.xlsx")
original_df
# Out:
#      Unnamed: 0                         Unnamed: 1  Unnamed: 2  \
# 0           NaN                                NaN         NaN
# 1           SL.                      Trader's Name  Party Type
# 2             1              A J Electric (Vadail)     Traders
# 3             2                     Afroz Electric     Traders
# 4             3                  Afsana Enterprise     Traders
# ...         ...                                ...         ...
# 4106       4105                   Vai-Vai Electric     Traders
# 4107       4106    Vai-Vai Electric & Electronicss     Traders
# 4108       4107                   Vai-Vai Hardware     Traders
# 4109       4108  Vai-Vai Hardware & Electric House     Traders
# 4110       4109       Wasim Electric & Electronics     Traders
#
#                                         Unnamed: 3   Unnamed: 4    Unnamed: 5  \
# 0                                              NaN          NaN           NaN
# ...

# %%
original_df.shape
# Out:
# (4111, 10)

# %%
#dd.mm.yy
path = "D:\Oct_23\cable_trader_oct_date 25.10.23.xlsx"
path
# Out:
# 'D:\\Oct_23\\cable_trader_oct_date 25.10.23.xlsx'

# %%
date1 = path.split('_')
date1
# Out:
# ['D:\\Oct', '23\\cable', 'trader', 'oct', 'date 25.10.23.xlsx']

# %%
date1 = path.split('_')[-1]
date1
# Out:
# 'date 25.10.23.xlsx'

# %%
date1 = path.split('_')[-1].split(' ')
date1
# Out:
# ['date', '25.10.23.xlsx']

# %%
date1 = path.split('_')[-1].split(' ')[-1]
date1
# Out:
# '25.10.23.xlsx'

# %%
date1 = path.split('_')[-1].split(' ')[-1].split('.')
date1
# Out:
# ['25', '10', '23', 'xlsx']

# %%
date = path.split('_')[-1].split(' ')[-1].split('.')[0]
date
# Out:
# '25'

# %%
month = path.split('_')[-1].split(' ')[-1].split('.')[1]
month
# Out:
# '10'

# %%
year = path.split('_')[-1].split(' ')[-1].split('.')[2]
year
# Out:
# '23'

# %%
date_contruction = f'{year}-{month}-{date}'
date_contruction
# Out:
# '23-10-25'

# %%
path
# Out:
# 'D:\\Oct_23\\cable_trader_oct_date 25.10.23.xlsx'

# %%
# Summary
# first split by _ then index then split by space & index then split by & index
date = path.split('_')[-1].split(' ')[-1].split('.')[0]
month = path.split('_')[-1].split(' ')[-1].split('.')[1]
year = path.split('_')[-1].split(' ')[-1].split('.')[2]

# Date Contrcution
date_contruction = f'{year}-{month}-{date}'
date_contruction
# Out:
# '23-10-25'

# %%
df1 = original_df.iloc[:, :7]
df1
# Out:
#      Unnamed: 0                         Unnamed: 1  Unnamed: 2  \
# 0           NaN                                NaN         NaN
# 1           SL.                      Trader's Name  Party Type
# 2             1              A J Electric (Vadail)     Traders
# 3             2                     Afroz Electric     Traders
# 4             3                  Afsana Enterprise     Traders
# ...         ...                                ...         ...
# 4106       4105                   Vai-Vai Electric     Traders
# 4107       4106    Vai-Vai Electric & Electronicss     Traders
# 4108       4107                   Vai-Vai Hardware     Traders
# 4109       4108  Vai-Vai Hardware & Electric House     Traders
# 4110       4109       Wasim Electric & Electronics     Traders
#
#                                         Unnamed: 3   Unnamed: 4    Unnamed: 5  \
# 0                                              NaN          NaN           NaN
# ...

# %%
df = original_df[]
df
# Out:
#   Input In [34]
#     df = original_df[]
#                      ^
# SyntaxError: invalid syntax

# %%
df = original_df[]
# Out:
#   Input In [35]
#     df = original_df[]
#                      ^
# SyntaxError: invalid syntax

# %%
original_df2 = pd.read_excel("D:\Oct_23\sales_cable.xlsx", header = None) # header = None > remomving unnamed column
original_df2
# Out:
#          0                                  1           2  \
# 0      NaN                                NaN         NaN
# 1      NaN                                NaN         NaN
# 2      SL.                      Trader's Name  Party Type
# 3        1              A J Electric (Vadail)     Traders
# 4        2                     Afroz Electric     Traders
# ...    ...                                ...         ...
# 4107  4105                   Vai-Vai Electric     Traders
# 4108  4106    Vai-Vai Electric & Electronicss     Traders
# 4109  4107                   Vai-Vai Hardware     Traders
# 4110  4108  Vai-Vai Hardware & Electric House     Traders
# 4111  4109       Wasim Electric & Electronics     Traders
#
#                                                  3            4             5  \
# 0                                              NaN          NaN           NaN
# 1                                              NaN          NaN           NaN
# ...

# %%
original_df3 = original_df2[2:]
original_df3
# Out:
#          0                                  1           2  \
# 2      SL.                      Trader's Name  Party Type
# 3        1              A J Electric (Vadail)     Traders
# 4        2                     Afroz Electric     Traders
# 5        3                  Afsana Enterprise     Traders
# 6        4                      Akhi Electric     Traders
# ...    ...                                ...         ...
# 4107  4105                   Vai-Vai Electric     Traders
# 4108  4106    Vai-Vai Electric & Electronicss     Traders
# 4109  4107                   Vai-Vai Hardware     Traders
# 4110  4108  Vai-Vai Hardware & Electric House     Traders
# 4111  4109       Wasim Electric & Electronics     Traders
#
#                                                  3            4             5  \
# 2                                 Trader's Address  Outstanding  Sales (BDT.)
# 3                              School Road,Vadail.    132809.18             0
# ...

# %%
original_df4 = original_df2[3:]
original_df4
# Out:
#          0                                  1        2  \
# 3        1              A J Electric (Vadail)  Traders
# 4        2                     Afroz Electric  Traders
# 5        3                  Afsana Enterprise  Traders
# 6        4                      Akhi Electric  Traders
# 7        5                 Al Modina Electric  Traders
# ...    ...                                ...      ...
# 4107  4105                   Vai-Vai Electric  Traders
# 4108  4106    Vai-Vai Electric & Electronicss  Traders
# 4109  4107                   Vai-Vai Hardware  Traders
# 4110  4108  Vai-Vai Hardware & Electric House  Traders
# 4111  4109       Wasim Electric & Electronics  Traders
#
#                                                  3          4         5  6  \
# 3                              School Road,Vadail.  132809.18         0  0
# 4     Chowdhury Market, Chowrasta, Ashulia, Dhaka.    -551.56         0  0
# 5                                 Landmark,Ashulia      -0.14         0  0
# ...

# %%
df3 = original_df4.rename(columns ={0:'SL', 1:'trader_name', 2:'party_type', 3:'address', 4:'opening', 5:'sales', 
                                   6:'return', 7:'collectoin', 8:'closing', 9:'branch_name'
                                   })
df3.head()
# Out:
#   SL            trader_name party_type  \
# 3  1  A J Electric (Vadail)    Traders
# 4  2         Afroz Electric    Traders
# 5  3      Afsana Enterprise    Traders
# 6  4          Akhi Electric    Traders
# 7  5     Al Modina Electric    Traders
#
#                                         address    opening sales return  \
# 3                           School Road,Vadail.  132809.18     0      0
# 4  Chowdhury Market, Chowrasta, Ashulia, Dhaka.    -551.56     0      0
# 5                              Landmark,Ashulia      -0.14     0      0
# 6           Super Market,Ashulia Bazar,Ashulia.      -0.65     0      0
# 7               Katal Bagan,Polash Bare,Ashulia      -1.77     0      0
#
#   collectoin    closing           branch_name
# 3          0  132809.18  Ashulia Sales Center
# 4          0    -551.56  Ashulia Sales Center
# 5          0      -0.14  Ashulia Sales Center
# 6          0      -0.65  Ashulia Sales Center
# 7          0      -1.77  Ashulia Sales Center

# %%
df5 = pd.read_excel("D:\Oct_23\sales_cable.xlsx",index_col=None, header=0)
df5.head()
# Out:
#   Unnamed: 0             Unnamed: 1  Unnamed: 2  \
# 0        NaN                    NaN         NaN
# 1        SL.          Trader's Name  Party Type
# 2          1  A J Electric (Vadail)     Traders
# 3          2         Afroz Electric     Traders
# 4          3      Afsana Enterprise     Traders
#
#                                      Unnamed: 3   Unnamed: 4    Unnamed: 5  \
# 0                                           NaN          NaN           NaN
# 1                              Trader's Address  Outstanding  Sales (BDT.)
# 2                           School Road,Vadail.    132809.18             0
# 3  Chowdhury Market, Chowrasta, Ashulia, Dhaka.      -551.56             0
# 4                              Landmark,Ashulia        -0.14             0
#
#             Unnamed: 6         Unnamed: 7                 Unnamed: 8  \
# 0                  NaN                NaN                        NaN
# 1  Sales Return (BDT.)  Collection (BDT.)  Current Outstanding(BDT.)
# ...
