# %% [markdown]
# ## Modin with Pandas

# %%
# !pip install modin[ray]

# %%
# !pip install --upgrade accelerate # (fixing error in modin)

# %%
# Normal Pandas (use single core)
import pandas as pd

# %%
# %%time
df = pd.read_csv('test_data.csv')
df
# Out:
# CPU times: total: 2.17 s
# Wall time: 1.67 s
#                             file  round    tick   seconds          att_team  \
# 0        esea_match_13770997.dem      1   16058  30.74165      Animal Style
# 1        esea_match_13770997.dem      1   16210  31.93185  Hentai Hooligans
# 2        esea_match_13770997.dem      1   16510  34.28094  Hentai Hooligans
# 3        esea_match_13770997.dem      1   17104  38.93212      Animal Style
# 4        esea_match_13770997.dem      1   17338  40.76441  Hentai Hooligans
# ...                          ...    ...     ...       ...               ...
# 1569472  esea_match_13793043.dem     18  178305  50.64319            Team 2
# 1569473  esea_match_13793043.dem     18  178463  51.87915            Team 1
# 1569474  esea_match_13793043.dem     18  178719  53.88171            Team 1
# 1569475  esea_match_13793043.dem     18  178905  55.33667            Team 2
# 1569476  esea_match_13793043.dem     18  179955  63.55042            Team 2
#
# ...

# %%
df.groupby('att_team')

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: total: 344 ms
# Wall time: 319 ms
#                         file   round    tick  seconds  vic_team  att_side  \
# att_team
# --to be determined--     170     170     170      170       170       170
# AGO Esports              189     189     189      189       189       189
# ALTERNATE aTTaX          133     133     133      133       133       133
# Animal Style              83      83      83       83        83        83
# EURONICS Gaming          199     199     199      199       199       199
# Endpoint                 249     249     249      249       249       249
# Hentai Hooligans         101     101     101      101       101       101
# Izako Boars              354     354     354      354       354       354
# ONCA Gaming               65      65      65       65        65        65
# PACT                     177     177     177      177       177       177
# PRiDE                    289     289     289      289       289       289
# ...

# %%
# Modin with Pandas
import modin.pandas as pd

# %%
# %%time
df = pd.read_csv('test_data.csv')
df
# Out:
# CPU times: total: 203 ms
# Wall time: 747 ms
#                             file  round    tick   seconds          att_team  \
# 0        esea_match_13770997.dem      1   16058  30.74165      Animal Style
# 1        esea_match_13770997.dem      1   16210  31.93185  Hentai Hooligans
# 2        esea_match_13770997.dem      1   16510  34.28094  Hentai Hooligans
# 3        esea_match_13770997.dem      1   17104  38.93212      Animal Style
# 4        esea_match_13770997.dem      1   17338  40.76441  Hentai Hooligans
# ...                          ...    ...     ...       ...               ...
# 1569472  esea_match_13793043.dem     18  178305  50.64319            Team 2
# 1569473  esea_match_13793043.dem     18  178463  51.87915            Team 1
# 1569474  esea_match_13793043.dem     18  178719  53.88171            Team 1
# 1569475  esea_match_13793043.dem     18  178905  55.33667            Team 2
# 1569476  esea_match_13793043.dem     18  179955  63.55042            Team 2
#
# ...

# %% [markdown]
# - %%time is masic function for python execution time, nothing can be written before it, otherwise it will return error!
# - loading data by modin >> only ms because in backuend it is using multiple CPU core at time, its multi thread parallalism

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: total: 78.1 ms
# Wall time: 47.9 ms
#                         file   round    tick  seconds  vic_team  att_side  \
# att_team
# --to be determined--     170     170     170      170       170       170
# AGO Esports              189     189     189      189       189       189
# ALTERNATE aTTaX          133     133     133      133       133       133
# Animal Style              83      83      83       83        83        83
# EURONICS Gaming          199     199     199      199       199       199
# Endpoint                 249     249     249      249       249       249
# Hentai Hooligans         101     101     101      101       101       101
# Izako Boars              354     354     354      354       354       354
# ONCA Gaming               65      65      65       65        65        65
# PACT                     177     177     177      177       177       177
# PRiDE                    289     289     289      289       289       289
# ...
